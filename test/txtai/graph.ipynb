# %%
from txtai import Embeddings
from txtai.pipeline import Textractor

# Create textractor model
textractor = Textractor()

# Create an embeddings
embeddings = Embeddings(path="sentence-transformers/nli-mpnet-base-v2")
input_docs = "../../test/knowledgebase/data_science.md"

# %%
# Extract text from documents
textractor(input_docs)
# Out:
# "# Data Science: From Data to Insights\n\n## What is Data Science?\n\nData science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data. It combines expertise from various fields, including statistics, computer science, information science, and domain knowledge.\n\nData scientists use their skills to analyze complex data, identify patterns, and generate actionable insights that can help organizations make better decisions. The field has grown exponentially in recent years due to the increasing availability of big data and advances in computing power.\n\n## The Data Science Process\n\n### Data Collection\n\nThe first step in any data science project is collecting relevant data. This can come from various sources:\n- Databases\n- APIs\n- Web scraping\n- Sensors and IoT devices\n- Surveys and forms\n- Public datasets\n\nData collection must be done ethically and in compliance with relevant regulations such as GDPR or CCPA.\n\n### Data Cleaning and Preprocessing\n\nRaw data is rarely ready for analysis. Data cleaning involves:\n- Handling missing values\n- Removing duplicates\n- Correcting inconsistencies\n- Normalizing data formats\n- Dealing with outliers\n\nThis step often takes the most time in a data science project but is crucial for reliable results.\n\n### Exploratory Data Analysis (EDA)\n\nEDA involves analyzing and visualizing the data to understand its characteristics:\n- Distribution of variables\n- Correlations between features\n- Identifying patterns and anomalies\n- Generating hypotheses\n\nTools like pandas, matplotlib, seaborn, and Tableau are commonly used for EDA.\n\n### Feature Engineering\n\nFeature engineering is the process of selecting, modifying, or creating new features (variables) to improve model performance:\n- Transforming variables (e.g., log transformation)\n- Creating interaction terms\n- Encoding categorical variables\n- Dimensionality reduction\n- Handling imbalanced data\n\nGood feature engineering often makes the difference between a mediocre model and an excellent one.\n\n### Model Building\n\nThis step involves selecting and training appropriate models:\n- Linear models (regression, logistic regression)\n- Tree-based models (decision trees, random forests, gradient boosting)\n- Support vector machines\n- Neural networks\n- Clustering algorithms\n- Time series models\n\nThe choice of model depends on the problem type, data characteristics, and desired outcomes.\n\n### Model Evaluation\n\nModels must be rigorously evaluated to ensure they perform well:\n- Cross-validation\n- Performance metrics (accuracy, precision, recall, F1-score, RMSE, etc.)\n- Confusion matrices\n- ROC curves\n- Residual analysis\n\nIt's important to avoid overfitting, where a model performs well on training data but poorly on new data.\n\n### Model Deployment\n\nOnce a model is validated, it can be deployed to production:\n- API development\n- Integration with existing systems\n- Monitoring performance\n- Handling scaling issues\n- Ensuring security\n\nMLOps (Machine Learning Operations) practices help streamline this process.\n\n### Communication of Results\n\nThe final step is communicating findings to stakeholders:\n- Data visualization\n- Executive summaries\n- Interactive dashboards\n- Presentations\n- Technical documentation\n\nEffective communication is essential for turning insights into action.\n\n## Key Tools and Technologies\n\n### Programming Languages\n\n- **Python**: The most popular language for data science, with libraries like pandas, NumPy, scikit-learn, and TensorFlow\n- **R**: Especially strong for statistical analysis and visualization\n- **SQL**: Essential for database queries and data manipulation\n- **Julia**: Growing in popularity for high-performance numerical computing\n\n### Big Data Technologies\n\n- **Hadoop**: Framework for distributed storage and processing\n- **Spark**: Fast, i ...

# %%
textractor = Textractor(paragraphs=True)
for paragraph in textractor(input_docs):
  print(paragraph, "\n----")
# Out:
# # Data Science: From Data to Insights
# ----
# ## What is Data Science?
# ----
# Data science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data. It combines expertise from various fields, including statistics, computer science, information science, and domain knowledge.
# ----
# Data scientists use their skills to analyze complex data, identify patterns, and generate actionable insights that can help organizations make better decisions. The field has grown exponentially in recent years due to the increasing availability of big data and advances in computing power.
# ----
# ## The Data Science Process
# ----
# ### Data Collection
# ----
# The first step in any data science project is collecting relevant data. This can come from various sources:
# - Databases
# - APIs
# - Web scraping
# - Sensors and IoT devices
# - Surveys and forms
# - Public datasets
# ----
# Data collection must be done ethically and in compliance with relevant regulations such as GDPR or CCPA.
# ----
# ### Data Cleaning and Preprocessing
# ----
# Raw data is rarely ready for analysis. Data cleaning involves:
# - Handling missing values
# - Removing duplicates
# - Correcting inconsistencies
# - Normalizing data formats
# - Dealing with outliers
# ----
# This step often takes the most time in a data science project but is crucial for reliable results.
# ----
# ### Exploratory Data Analysis (EDA)
# ----
# EDA involves analyzing and visualizing the data to understand its characteristics:
# - Distribution of variables
# - Correlations between features
# - Identifying patterns and anomalies
# - Generating hypotheses
# ----
# Tools like pandas, matplotlib, seaborn, and Tableau are commonly used for EDA.
# ----
# ### Feature Engineering
# ----
# Feature engineering is the process of selecting, modifying, or creating new features (variables) to improve model performance:
# - Transforming variables (e.g., log transformation)
# - Creating interaction terms
# - Encoding categorical variables
# - Dimensionality reduction
# - Handling imbalanced data
# ----
# Good feature engineering often makes the difference between a mediocre model and an excellent one.
# ----
# ### Model Building
# ----
# This step involves selecting and training appropriate models:
# - Linear models (regression, logistic regression)
# - Tree-based models (decision trees, random forests, gradient boosting)
# - Support vector machines
# - Neural networks
# - Clustering algorithms
# - Time series models
# ----
# The choice of model depends on the problem type, data characteristics, and desired outcomes.
# ----
# ### Model Evaluation
# ----
# Models must be rigorously evaluated to ensure they perform well:
# - Cross-validation
# - Performance metrics (accuracy, precision, recall, F1-score, RMSE, etc.)
# - Confusion matrices
# - ROC curves
# - Residual analysis
# ----
# It's important to avoid overfitting, where a model performs well on training data but poorly on new data.
# ----
# ### Model Deployment
# ----
# Once a model is validated, it can be deployed to production:
# - API development
# - Integration with existing systems
# - Monitoring performance
# - Handling scaling issues
# - Ensuring security
# ----
# MLOps (Machine Learning Operations) practices help streamline this process.
# ----
# ### Communication of Results
# ----
# The final step is communicating findings to stakeholders:
# - Data visualization
# - Executive summaries
# - Interactive dashboards
# - Presentations
# - Technical documentation
# ----
# Effective communication is essential for turning insights into action.
# ----
# ## Key Tools and Technologies
# ----
# ### Programming Languages
# ----
# - **Python**: The most popular language for data science, with libraries like pandas, NumPy, scikit-learn, and TensorFlow
# - **R**: Especially strong for statistical analysis and visualization
# - **SQL**: Essential for database queries and data manipulation
# - **Julia**: Growing in popularity for high-performance numerical computing
# ----
# ### Big Data Technologies
# ----
# - **Hadoop**: Framework for distributed storage and processing
# - **Spark**: Fast, in-memory data processing engine
# - **Kafka**: Real-time data streaming platform
# - **NoSQL databases**: MongoDB, Cassandra, etc., for handling unstructured data
# ----
# ### Visualization Tools
# ----
# - **Matplotlib and Seaborn**: Python libraries for static visualizations
# - **Plotly and Bokeh**: Interactive visualization libraries
# - **Tableau**: User-friendly tool for creating interactive dashboards
# - **Power BI**: Microsoft's business analytics service
# - **D3.js**: JavaScript library for custom web-based visualizations
# ----
# ### Cloud Platforms
# ----
# - **AWS**: Amazon's cloud platform with services like S3, EC2, SageMaker
# - **Google Cloud Platform**: Includes BigQuery, Dataflow, and AI Platform
# - **Microsoft Azure**: Offers Azure ML, HDInsight, and other data services
# - **IBM Cloud**: Watson Studio and other AI/ML services
# ----
# ## Applications of Data Science
# ----
# ### Business Intelligence
# ----
# Data science enables businesses to:
# - Analyze customer behavior
# - Optimize pricing strategies
# - Improve supply chain efficiency
# - Detect fraud
# - Personalize marketing campaigns
# - Forecast sales and demand
# ----
# ### Healthcare
# ----
# In healthcare, data science is used for:
# - Disease prediction and diagnosis
# - Medical image analysis
# - Drug discovery
# - Patient monitoring
# - Healthcare resource optimization
# - Genomics research
# ----
# ### Smart Cities
# ----
# Data science helps make cities more efficient and livable through:
# - Traffic management
# - Energy optimization
# - Public safety enhancement
# - Urban planning
# - Environmental monitoring
# - Public service improvement
# ----
# ### Finance
# ----
# Financial institutions use data science for:
# - Risk assessment
# - Algorithmic trading
# - Customer segmentation
# - Fraud detection
# - Credit scoring
# - Portfolio optimization
# ----
# ## Ethical Considerations in Data Science
# ----
# ### Privacy
# ----
# Data scientists must respect individual privacy:
# - Anonymizing personal data
# - Implementing secure data storage
# - Obtaining proper consent
# - Complying with privacy regulations
# - Minimizing data collection to what's necessary
# ----
# ### Bias and Fairness
# ----
# Algorithms can perpetuate or amplify existing biases:
# - Testing for bias in training data
# - Evaluating model fairness across different groups
# - Using diverse training data
# - Implementing fairness constraints
# - Regular auditing of deployed models
# ----
# ### Transparency
# ----
# Data science processes should be transparent:
# - Documenting methodologies
# - Explaining model decisions
# - Providing access to code and data when appropriate
# - Being clear about limitations
# - Enabling reproducibility
# ----
# ### Accountability
# ----
# Data scientists should be accountable for their work:
# - Taking responsibility for model outcomes
# - Establishing clear ownership
# - Creating feedback mechanisms
# - Developing ethical guidelines
# - Continuous monitoring of deployed systems
# ----
# ## Future Trends in Data Science
# ----
# ### AutoML
# ----
# Automated Machine Learning (AutoML) tools are making data science more accessible by automating:
# - Feature selection
# - Model selection
# - Hyperparameter tuning
# - Model evaluation
# - Deployment
# ----
# ### Edge Analytics
# ----
# Processing data closer to where it's generated:
# - Reduced latency
# - Lower bandwidth requirements
# - Enhanced privacy
# - Real-time decision making
# - IoT integration
# ----
# ### Explainable AI
# ----
# Making complex models more interpretable:
# - LIME (Local Interpretable Model-agnostic Explanations)
# - SHAP (SHapley Additive exPlanations)
# - Feature importance visualization
# - Model-specific interpretation methods
# - Counterfactual explanations
# ----
# ### Data Science Democratization
# ----
# Making data science accessible to non-specialists:
# - No-code/low-code platforms
# - Self-service analytics
# - Improved user interfaces
# - Educational resources
# - Simplified deployment options
# ----
# ## Conclusion
# ----
# Data science continues to evolve rapidly, driven by technological advances and growing data availability. As organizations increasingly recognize the value of data-driven decision making, the demand for data science expertise will continue to grow. However, with this power comes responsibility—ethical considerations must remain at the forefront as we develop and deploy data science solutions that impact people's lives.
# ----

# %%
textractor = Textractor(sections=True)
print("\n[PAGE BREAK]\n".join(section for section in textractor(input_docs)))
# Out:
# # Data Science: From Data to Insights
# [PAGE BREAK]
# ## What is Data Science?
#
# Data science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data. It combines expertise from various fields, including statistics, computer science, information science, and domain knowledge.
#
# Data scientists use their skills to analyze complex data, identify patterns, and generate actionable insights that can help organizations make better decisions. The field has grown exponentially in recent years due to the increasing availability of big data and advances in computing power.
# [PAGE BREAK]
# ## The Data Science Process
# [PAGE BREAK]
# ### Data Collection
#
# The first step in any data science project is collecting relevant data. This can come from various sources:
# - Databases
# - APIs
# - Web scraping
# - Sensors and IoT devices
# - Surveys and forms
# - Public datasets
#
# Data collection must be done ethically and in compliance with relevant regulations such as GDPR or CCPA.
# [PAGE BREAK]
# ### Data Cleaning and Preprocessing
#
# Raw data is rarely ready for analysis. Data cleaning involves:
# - Handling missing values
# - Removing duplicates
# - Correcting inconsistencies
# - Normalizing data formats
# - Dealing with outliers
#
# This step often takes the most time in a data science project but is crucial for reliable results.
# [PAGE BREAK]
# ### Exploratory Data Analysis (EDA)
#
# EDA involves analyzing and visualizing the data to understand its characteristics:
# - Distribution of variables
# - Correlations between features
# - Identifying patterns and anomalies
# - Generating hypotheses
#
# Tools like pandas, matplotlib, seaborn, and Tableau are commonly used for EDA.
# [PAGE BREAK]
# ### Feature Engineering
#
# Feature engineering is the process of selecting, modifying, or creating new features (variables) to improve model performance:
# - Transforming variables (e.g., log transformation)
# - Creating interaction terms
# - Encoding categorical variables
# - Dimensionality reduction
# - Handling imbalanced data
#
# Good feature engineering often makes the difference between a mediocre model and an excellent one.
# [PAGE BREAK]
# ### Model Building
#
# This step involves selecting and training appropriate models:
# - Linear models (regression, logistic regression)
# - Tree-based models (decision trees, random forests, gradient boosting)
# - Support vector machines
# - Neural networks
# - Clustering algorithms
# - Time series models
#
# The choice of model depends on the problem type, data characteristics, and desired outcomes.
# [PAGE BREAK]
# ### Model Evaluation
#
# Models must be rigorously evaluated to ensure they perform well:
# - Cross-validation
# - Performance metrics (accuracy, precision, recall, F1-score, RMSE, etc.)
# - Confusion matrices
# - ROC curves
# - Residual analysis
#
# It's important to avoid overfitting, where a model performs well on training data but poorly on new data.
# [PAGE BREAK]
# ### Model Deployment
#
# Once a model is validated, it can be deployed to production:
# - API development
# - Integration with existing systems
# - Monitoring performance
# - Handling scaling issues
# - Ensuring security
#
# MLOps (Machine Learning Operations) practices help streamline this process.
# [PAGE BREAK]
# ### Communication of Results
#
# The final step is communicating findings to stakeholders:
# - Data visualization
# - Executive summaries
# - Interactive dashboards
# - Presentations
# - Technical documentation
#
# Effective communication is essential for turning insights into action.
# [PAGE BREAK]
# ## Key Tools and Technologies
# [PAGE BREAK]
# ### Programming Languages
#
# - **Python**: The most popular language for data science, with libraries like pandas, NumPy, scikit-learn, and TensorFlow
# - **R**: Especially strong for statistical analysis and visualization
# - **SQL**: Essential for database queries and data manipulation
# - **Julia**: Growing in popularity for high-performance numerical computing
# [PAGE BREAK]
# ### Big Data Technologies
#
# - **Hadoop**: Framework for distributed storage and processing
# - **Spark**: Fast, in-memory data processing engine
# - **Kafka**: Real-time data streaming platform
# - **NoSQL databases**: MongoDB, Cassandra, etc., for handling unstructured data
# [PAGE BREAK]
# ### Visualization Tools
#
# - **Matplotlib and Seaborn**: Python libraries for static visualizations
# - **Plotly and Bokeh**: Interactive visualization libraries
# - **Tableau**: User-friendly tool for creating interactive dashboards
# - **Power BI**: Microsoft's business analytics service
# - **D3.js**: JavaScript library for custom web-based visualizations
# [PAGE BREAK]
# ### Cloud Platforms
#
# - **AWS**: Amazon's cloud platform with services like S3, EC2, SageMaker
# - **Google Cloud Platform**: Includes BigQuery, Dataflow, and AI Platform
# - **Microsoft Azure**: Offers Azure ML, HDInsight, and other data services
# - **IBM Cloud**: Watson Studio and other AI/ML services
# [PAGE BREAK]
# ## Applications of Data Science
# [PAGE BREAK]
# ### Business Intelligence
#
# Data science enables businesses to:
# - Analyze customer behavior
# - Optimize pricing strategies
# - Improve supply chain efficiency
# - Detect fraud
# - Personalize marketing campaigns
# - Forecast sales and demand
# [PAGE BREAK]
# ### Healthcare
#
# In healthcare, data science is used for:
# - Disease prediction and diagnosis
# - Medical image analysis
# - Drug discovery
# - Patient monitoring
# - Healthcare resource optimization
# - Genomics research
# [PAGE BREAK]
# ### Smart Cities
#
# Data science helps make cities more efficient and livable through:
# - Traffic management
# - Energy optimization
# - Public safety enhancement
# - Urban planning
# - Environmental monitoring
# - Public service improvement
# [PAGE BREAK]
# ### Finance
#
# Financial institutions use data science for:
# - Risk assessment
# - Algorithmic trading
# - Customer segmentation
# - Fraud detection
# - Credit scoring
# - Portfolio optimization
# [PAGE BREAK]
# ## Ethical Considerations in Data Science
# [PAGE BREAK]
# ### Privacy
#
# Data scientists must respect individual privacy:
# - Anonymizing personal data
# - Implementing secure data storage
# - Obtaining proper consent
# - Complying with privacy regulations
# - Minimizing data collection to what's necessary
# [PAGE BREAK]
# ### Bias and Fairness
#
# Algorithms can perpetuate or amplify existing biases:
# - Testing for bias in training data
# - Evaluating model fairness across different groups
# - Using diverse training data
# - Implementing fairness constraints
# - Regular auditing of deployed models
# [PAGE BREAK]
# ### Transparency
#
# Data science processes should be transparent:
# - Documenting methodologies
# - Explaining model decisions
# - Providing access to code and data when appropriate
# - Being clear about limitations
# - Enabling reproducibility
# [PAGE BREAK]
# ### Accountability
#
# Data scientists should be accountable for their work:
# - Taking responsibility for model outcomes
# - Establishing clear ownership
# - Creating feedback mechanisms
# - Developing ethical guidelines
# - Continuous monitoring of deployed systems
# [PAGE BREAK]
# ## Future Trends in Data Science
# [PAGE BREAK]
# ### AutoML
#
# Automated Machine Learning (AutoML) tools are making data science more accessible by automating:
# - Feature selection
# - Model selection
# - Hyperparameter tuning
# - Model evaluation
# - Deployment
# [PAGE BREAK]
# ### Edge Analytics
#
# Processing data closer to where it's generated:
# - Reduced latency
# - Lower bandwidth requirements
# - Enhanced privacy
# - Real-time decision making
# - IoT integration
# [PAGE BREAK]
# ### Explainable AI
#
# Making complex models more interpretable:
# - LIME (Local Interpretable Model-agnostic Explanations)
# - SHAP (SHapley Additive exPlanations)
# - Feature importance visualization
# - Model-specific interpretation methods
# - Counterfactual explanations
# [PAGE BREAK]
# ### Data Science Democratization
#
# Making data science accessible to non-specialists:
# - No-code/low-code platforms
# - Self-service analytics
# - Improved user interfaces
# - Educational resources
# - Simplified deployment options
# [PAGE BREAK]
# ## Conclusion
#
# Data science continues to evolve rapidly, driven by technological advances and growing data availability. As organizations increasingly recognize the value of data-driven decision making, the demand for data science expertise will continue to grow. However, with this power comes responsibility—ethical considerations must remain at the forefront as we develop and deploy data science solutions that impact people's lives.

# %%
from txtai.app import Application

# Create and run application
app = Application("path: ../../.txtai/kb-test")
# Access the embeddings object
embeddings = app.embeddings

# Print the full embeddings configuration in a more readable format
import json
print(json.dumps(embeddings.config, indent=2))

# Check if graph is available
print(f"\nHas Graph: {hasattr(embeddings, 'graph')}")
if hasattr(embeddings, 'graph') and embeddings.graph:
    print(f"Graph Node Count: {embeddings.graph.count()}")
# Out:
# {
#   "path": "sentence-transformers/nli-mpnet-base-v2",
#   "normalize": true,
#   "hybrid": true,
#   "gpu": true,
#   "storagetype": "sqlite",
#   "storagepath": ".txtai/embeddings/kb-test",
#   "writable": true,
#   "content": true,
#   "graph": {
#     "backend": "networkx",
#     "batchsize": 256,
#     "limit": 5,
#     "minscore": 0.6,
#     "approximate": true,
#     "topics": {
#       "algorithm": "louvain",
#       "terms": 4
#     },
#     "centrality": "pagerank",
#     "directed": false,
#     "weight": "similarity",
#     "search": {
#       "max_hops": 2,
#       "use_centrality": true,
#       "min_score": 0.3
#     }
#   },
#   "scoring": {
#     "method": "bm25",
#     "normalize": true,
#     "terms": {
#       "cachelimit": 1000000000,
#       "cutoff": 0.001
#     }
#   },
#   "dimensions": 768,
#   "backend": "faiss",
#   "offset": 98,
#   "build": {
#     "create": "2025-03-03T13:41:42Z",
#     "python": "3.10.16",
#     "settings": {
#       "components": "IDMap,Flat"
#     },
#     "system": "Darwin (arm64)",
#     "txtai": "8.3.1"
#   },
#   "update": "2025-03-03T13:41:42Z",
#   "format": "json"
# }
#
# Has Graph: True
# Graph Node Count: 98

# %%
app.search("what is neural network")
# Out:
# [{'id': 'ac8955e54f7cabd2e7df4a0372883908-6',
#   'text': 'A network with more than one hidden layer is called a deep neural network, which is where the term "deep learning" comes from.',
#   'score': 0.6270837195369511},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-2',
#   'text': 'The fundamental unit of a neural network is the neuron, also called a node or perceptron. A neuron takes input, performs a computation on that input, and produces an output. The computation typically involves:',
#   'score': 0.5486800418267701},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-1',
#   'text': 'Neural networks help us cluster and classify data. They can be thought of as components of larger machine learning applications involving algorithms for reinforcement learning, classification, and regression. What makes neural networks special is their ability to extract high-level features from raw data automatically, without manual feature engineering.',
#   'score': 0.532959755925006},
#  {'id': '9aa0b7c49858a94b3ecc16d89059456b-8',
#   'text': 'Deep learning is a subset of machine learning that uses neural networks with multiple layers (deep neural networks) to analyze various factors of data. It is inspired by the structure and function of the human brain, specifically the interconnecting of many neurons.',
#   'score': 0.4816536321318602},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-42',
#   'text': 'Ensuring that neural networks are fair, transparent, and beneficial is an increasingly important area of research as these systems become more integrated into society.',
#   'score': 0.456259850966171},
#  {'id': '9aa0b7c49858a94b3ecc16d89059456b-9',
#   'text': 'Deep learning architectures include:\n- Convolutional Neural Networks (CNNs) for image processing\n- Recurrent Neural Networks (RNNs) for sequence data\n- Long Short-Term Memory (LSTM) networks for time series\n- Transformers for natural language processing\n- Graph Neural Networks for graph-structured data',
#   'score': 0.347051203250885},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-40',
#   'text': 'Hardware designed to mimic the structure and function of the brain promises to make neural networks more efficient and capable.',
#   'score': 0.33636313676834106},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-43',
#   'text': 'Neural networks have transformed machine learning and artificial intelligence, enabling systems that can see, hear, speak, and understand the world in ways that were once the domain of science fiction. As research continues and technology advances, neural networks will likely become even more powerful and ubiquitous, solving increasingly complex problems and creating new opportunities across virtually every field of human endeavor.',
#   'score': 0.31613802909851074},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-15',
#   'text': 'GANs consist of two neural networks—a generator and a discriminator—that compete against each other:',
#   'score': 0.30627989768981934},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-0',
#   'text': 'Neural networks are a set of algorithms, modeled loosely after the human brain, that are designed to recognize patterns. They interpret sensory data through a kind of machine perception, labeling or clustering raw input. The patterns they recognize are numerical, contained in vectors, into which all real-world data, be it images, sound, text or time series, must be translated.',
#   'score': 0.2948145866394043}]

# %%
embeddings.search("neural network", limit=5)
# Out:
# [{'id': 'ac8955e54f7cabd2e7df4a0372883908-2',
#   'text': 'The fundamental unit of a neural network is the neuron, also called a node or perceptron. A neuron takes input, performs a computation on that input, and produces an output. The computation typically involves:',
#   'score': 0.5156346790595058},
#  {'id': '9aa0b7c49858a94b3ecc16d89059456b-9',
#   'text': 'Deep learning architectures include:\n- Convolutional Neural Networks (CNNs) for image processing\n- Recurrent Neural Networks (RNNs) for sequence data\n- Long Short-Term Memory (LSTM) networks for time series\n- Transformers for natural language processing\n- Graph Neural Networks for graph-structured data',
#   'score': 0.34626340866088867},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-40',
#   'text': 'Hardware designed to mimic the structure and function of the brain promises to make neural networks more efficient and capable.',
#   'score': 0.3256106972694397},
#  {'id': '9aa0b7c49858a94b3ecc16d89059456b-8',
#   'text': 'Deep learning is a subset of machine learning that uses neural networks with multiple layers (deep neural networks) to analyze various factors of data. It is inspired by the structure and function of the human brain, specifically the interconnecting of many neurons.',
#   'score': 0.3247562646865845},
#  {'id': 'ac8955e54f7cabd2e7df4a0372883908-42',
#   'text': 'Ensuring that neural networks are fair, transparent, and beneficial is an increasingly important area of research as these systems become more integrated into society.',
#   'score': 0.3243175745010376}]

# %%
graph = embeddings.search("neural network", 100, graph=True)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def plot(graph):
    labels = {x: f"{graph.attribute(x, 'id')} ({x})" for x in graph.scan()}
    options = {
        "node_size": 750,
        "node_color": "#0277bd",
        "edge_color": "#454545",
        "font_color": "#fff",
        "font_size": 6,
        "alpha": 1.0
    }

    fig, ax = plt.subplots(figsize=(17, 8))
    pos = nx.spring_layout(graph.backend, seed=0, k=0.9, iterations=50)
    nx.draw_networkx(graph.backend, pos=pos, labels=labels, **options)
    ax.set_facecolor("#303030")
    ax.axis("off")
    fig.set_facecolor("#303030")

    plt.show()

plot(graph)

# %%
for x in list(graph.centrality().keys())[:20]:
    print(graph.node(x))
# Out:
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-8', 'text': 'Deep learning is a subset of machine learning that uses neural networks with multiple layers (deep neural networks) to analyze various factors of data. It is inspired by the structure and function of the human brain, specifically the interconnecting of many neurons.', 'topic': 'neural_many_layers_subset', 'topicrank': 0, 'score': 0.4155230164994065}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-0', 'text': 'Machine learning is a field of study that gives computers the ability to learn without being explicitly programmed. It is a branch of artificial intelligence based on the idea that systems can learn from data, identify patterns, and make decisions with minimal human intervention.', 'topic': 'gives_patterns_machine_artificial', 'topicrank': 0, 'score': 0.20265157520771027}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-1', 'text': 'Neural networks help us cluster and classify data. They can be thought of as components of larger machine learning applications involving algorithms for reinforcement learning, classification, and regression. What makes neural networks special is their ability to extract high-level features from raw data automatically, without manual feature engineering.', 'topic': 'neural_high_help_reinforcement', 'topicrank': 0, 'score': 0.3882040994562861}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-24', 'text': '1. Computing the gradient of the loss function with respect to the output\n2. Using the chain rule to propagate this gradient backward through the network\n3. Updating weights to minimize the loss', 'topic': 'minimize_loss_using_updating', 'topicrank': 0, 'score': 0.27921559869045154}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-28', 'text': "Data science continues to evolve rapidly, driven by technological advances and growing data availability. As organizations increasingly recognize the value of data-driven decision making, the demand for data science expertise will continue to grow. However, with this power comes responsibility—ethical considerations must remain at the forefront as we develop and deploy data science solutions that impact people's lives.", 'topic': 'recognize_driven_science_lives', 'topicrank': 0, 'score': 0.10640512406826019}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-20', 'text': 'During forward propagation, input data passes through the network layer by layer, with each neuron applying its weights, bias, and activation function to produce an output that becomes input for the next layer.', 'topic': 'propagation_layer_during_passes', 'topicrank': 0, 'score': 0.3954400068401708}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-43', 'text': 'Neural networks have transformed machine learning and artificial intelligence, enabling systems that can see, hear, speak, and understand the world in ways that were once the domain of science fiction. As research continues and technology advances, neural networks will likely become even more powerful and ubiquitous, solving increasingly complex problems and creating new opportunities across virtually every field of human endeavor.', 'topic': 'see_neural_every_science', 'topicrank': 0, 'score': 0.3876325553434089}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-10', 'text': 'Computer vision is a field of artificial intelligence that trains computers to interpret and understand the visual world. Using digital images from cameras and videos and deep learning models, machines can accurately identify and classify objects and then react to what they "see."', 'topic': 'see_trains_what_videos', 'topicrank': 0, 'score': 0.20480449497699738}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-24', 'text': 'Machine learning has transformed from an academic curiosity to a powerful tool with applications across virtually every industry. As algorithms become more sophisticated and computing power increases, the potential applications of machine learning will continue to expand, bringing both opportunities and challenges for society to navigate.', 'topic': 'expand_every_industry_potential', 'topicrank': 0, 'score': 0.1688309609889984}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-6', 'text': 'Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment in order to maximize the notion of cumulative reward. Reinforcement learning differs from supervised learning in that labeled input/output pairs need not be presented, and sub-optimal actions need not be explicitly corrected.', 'topic': 'differs_reinforcement_machine_take', 'topicrank': 0, 'score': 0.18511617183685303}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-1', 'text': 'The term "Machine Learning" was coined by Arthur Samuel in 1959, defining it as a "Field of study that gives computers the ability to learn without being explicitly programmed." Machine learning algorithms build a mathematical model based on sample data, known as "training data," in order to make predictions or decisions without being explicitly programmed to perform the task.', 'topic': 'gives_machine_mathematical_predictions', 'topicrank': 0, 'score': 0.17403429746627808}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-4', 'text': 'Unsupervised learning is a type of machine learning algorithm used to draw inferences from datasets consisting of input data without labeled responses. The most common unsupervised learning method is cluster analysis, which is used for exploratory data analysis to find hidden patterns or grouping in data.', 'topic': 'most_find_common_responses', 'topicrank': 0, 'score': 0.18115529417991638}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-19', 'text': 'Machine learning systems can perpetuate or amplify existing biases in the data they are trained on. Ensuring fairness, accountability, and transparency in machine learning systems is a significant challenge.', 'topic': 'data_fairness_biases_learning', 'topicrank': 0, 'score': 0.17631004750728607}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-10', 'text': 'CNNs have revolutionized computer vision tasks like:\n- Image classification\n- Object detection\n- Face recognition\n- Medical image analysis', 'topic': 'face_cnns_computer_classification', 'topicrank': 0, 'score': 0.19629734754562378}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-11', 'text': 'Applications include:\n- Image classification\n- Object detection and tracking\n- Facial recognition\n- Autonomous vehicles\n- Medical image analysis', 'topic': 'applications_classification_autonomous_facial', 'topicrank': 0, 'score': 0.15187481045722961}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-30', 'text': '- Object detection and recognition\n- Image segmentation\n- Facial recognition\n- Autonomous vehicles\n- Medical image analysis', 'topic': 'autonomous_facial_segmentation_vehicles', 'topicrank': 0, 'score': 0.15743163228034973}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-19', 'text': '- Natural language processing\n- Language translation\n- Text summarization\n- Question answering systems', 'topic': 'answering_processing_natural_question', 'topicrank': 0, 'score': 0.17386218905448914}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-13', 'text': 'Common NLP tasks include:\n- Text classification\n- Sentiment analysis\n- Machine translation\n- Named entity recognition\n- Question answering\n- Text summarization', 'topic': 'answering_summarization_common_analysis', 'topicrank': 0, 'score': 0.15872639417648315}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-31', 'text': '- Sentiment analysis\n- Machine translation\n- Text generation\n- Named entity recognition\n- Question answering', 'topic': 'answering_generation_entity_named', 'topicrank': 0, 'score': 0.16158246994018555}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-0', 'text': 'Data science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data. It combines expertise from various fields, including statistics, computer science, information science, and domain knowledge.', 'topic': 'knowledge_structured_science_scientific', 'topicrank': 0, 'score': 0.15048396587371826}

# %%
from txtai.pipeline import Extractor

# Create extractor instance
extractor = Extractor(embeddings, "distilbert-base-cased-distilled-squad")
# Out:
# Device set to use mps

# %%
# Import necessary libraries if not already imported
from txtai.pipeline import Extractor

# Create extractor instance using your existing embeddings
extractor = Extractor(embeddings, "distilbert-base-cased-distilled-squad")

# Read the data_science.md file
with open("../../test/knowledgebase/data_science.md", "r") as f:
    data_science_text = f.read()

# Split the document into paragraphs for better extraction
from txtai.pipeline import Textractor
textractor = Textractor(paragraphs=True)
paragraphs = list(textractor(data_science_text))

print(f"Document split into {len(paragraphs)} paragraphs")

# Define questions for different search types
# 1. Keyword-based questions (direct term matching)
keyword_questions = [
    "What programming languages are used in data science?",
    "What is AutoML?",
    "What tools are used for data visualization?"
]

# 2. Similarity-based questions (semantic understanding)
similarity_questions = [
    "How can data scientists ensure their models are fair?",
    "What steps are involved in preparing raw data for analysis?",
    "How can organizations derive business value from data science?"
]

# 3. Relationship-based questions (graph connections)
relationship_questions = [
    "How does feature engineering relate to model performance?",
    "What is the connection between privacy and ethical data science?",
    "How do edge analytics and IoT relate to each other?"
]

# Function to execute extraction for a list of questions
def execute_extraction(questions, data):
    results = []
    for question in questions:
        answer = extractor([(question, question, question, False)], data)
        results.append((question, answer[0][1] if answer else "No answer found"))
    return results

# Test keyword-based questions
print("\n--- KEYWORD-BASED QUESTIONS ---")
keyword_results = execute_extraction(keyword_questions, paragraphs)
for question, answer in keyword_results:
    print(f"Q: {question}")
    print(f"A: {answer}")
    print()

# Test similarity-based questions
print("\n--- SIMILARITY-BASED QUESTIONS ---")
similarity_results = execute_extraction(similarity_questions, paragraphs)
for question, answer in similarity_results:
    print(f"Q: {question}")
    print(f"A: {answer}")
    print()

# Test relationship-based questions
print("\n--- RELATIONSHIP-BASED QUESTIONS ---")
relationship_results = execute_extraction(relationship_questions, paragraphs)
for question, answer in relationship_results:
    print(f"Q: {question}")
    print(f"A: {answer}")
    print()

# Test a complex multi-part question
complex_question = "What are the ethical considerations in data science and how do they impact model deployment?"
print("\n--- COMPLEX QUESTION ---")
complex_result = extractor([(complex_question, complex_question, complex_question, False)], paragraphs)
print(f"Q: {complex_question}")
print(f"A: {complex_result[0][1] if complex_result else 'No answer found'}")
print()
# Out:
# Device set to use mps
# Document split into 67 paragraphs
#
# --- KEYWORD-BASED QUESTIONS ---
# Q: What programming languages are used in data science?
# A: Applications
#
# Q: What is AutoML?
# A: Automated Machine Learning
#
# Q: What tools are used for data visualization?
# A: User-friendly tool for creating interactive dashboards
#
#
# --- SIMILARITY-BASED QUESTIONS ---
# Q: How can data scientists ensure their models are fair?
# A: rigorously evaluated
#
# Q: What steps are involved in preparing raw data for analysis?
# A: Data Cleaning and Preprocessing
#
# Q: How can organizations derive business value from data science?
# A: Analyze customer behavior
# - Optimize pricing strategies
#
#
# --- RELATIONSHIP-BASED QUESTIONS ---
# Q: How does feature engineering relate to model performance?
# A: None
#
# Q: What is the connection between privacy and ethical data science?
# A: we develop and deploy data science solutions that impact people's lives
#
# Q: How do edge analytics and IoT relate to each other?
# A: closer to where it's generated
#
#
# --- COMPLEX QUESTION ---
# Q: What are the ethical considerations in data science and how do they impact model deployment?
# A: Continuous monitoring
#
# --- GRAPH-BASED SEARCH ---
#
# --- RELATIONSHIP QUESTIONS GRAPH SEARCH ---
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-6', 'text': 'Feature engineering is the process of selecting, modifying, or creating new features (variables) to improve model performance:\n- Transforming variables (e.g., log transformation)\n- Creating interaction terms\n- Encoding categorical variables\n- Dimensionality reduction\n- Handling imbalanced data', 'topic': 'handling_transforming_log_terms', 'topicrank': 0, 'score': 0.6975386770589824}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-26', 'text': 'Making complex models more interpretable:\n- LIME (Local Interpretable Model-agnostic Explanations)\n- SHAP (SHapley Additive exPlanations)\n- Feature importance visualization\n- Model-specific interpretation methods\n- Counterfactual explanations', 'topic': 'counterfactual_shapley_more_additive', 'topicrank': 0, 'score': 0.4705455623859822}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-10', 'text': 'Once a model is validated, it can be deployed to production:\n- API development\n- Integration with existing systems\n- Monitoring performance\n- Handling scaling issues\n- Ensuring security', 'topic': 'security_deployed_scaling_ensuring', 'topicrank': 0, 'score': 0.469046254280146}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-8', 'text': 'Models must be rigorously evaluated to ensure they perform well:\n- Cross-validation\n- Performance metrics (accuracy, precision, recall, F1-score, RMSE, etc.)\n- Confusion matrices\n- ROC curves\n- Residual analysis', 'topic': 'validation_roc_accuracy_confusion', 'topicrank': 0, 'score': 0.2852960228919983}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-7', 'text': 'This step involves selecting and training appropriate models:\n- Linear models (regression, logistic regression)\n- Tree-based models (decision trees, random forests, gradient boosting)\n- Support vector machines\n- Neural networks\n- Clustering algorithms\n- Time series models', 'topic': 'time_clustering_neural_appropriate', 'topicrank': 0, 'score': 0.2635480463504791}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-28', 'text': "Data science continues to evolve rapidly, driven by technological advances and growing data availability. As organizations increasingly recognize the value of data-driven decision making, the demand for data science expertise will continue to grow. However, with this power comes responsibility—ethical considerations must remain at the forefront as we develop and deploy data science solutions that impact people's lives.", 'topic': 'recognize_driven_science_lives', 'topicrank': 0, 'score': 0.5764532255468227}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-0', 'text': 'Data science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data. It combines expertise from various fields, including statistics, computer science, information science, and domain knowledge.', 'topic': 'knowledge_structured_science_scientific', 'topicrank': 0, 'score': 0.4813743500682888}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-20', 'text': "Data scientists must respect individual privacy:\n- Anonymizing personal data\n- Implementing secure data storage\n- Obtaining proper consent\n- Complying with privacy regulations\n- Minimizing data collection to what's necessary", 'topic': 'individual_scientists_anonymizing_data', 'topicrank': 0, 'score': 0.3551371097564697}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-3', 'text': 'Data collection must be done ethically and in compliance with relevant regulations such as GDPR or CCPA.', 'topic': 'data_collection_gdpr_ccpa', 'topicrank': 0, 'score': 0.2778545618057251}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-5', 'text': '- **Input Layer**: Receives the initial data\n- **Hidden Layers**: Intermediate layers between input and output\n- **Output Layer**: Produces the final result', 'topic': 'data_initial_layers_hidden', 'topicrank': 0, 'score': 0.25379726914956763}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-15', 'text': "- **AWS**: Amazon's cloud platform with services like S3, EC2, SageMaker\n- **Google Cloud Platform**: Includes BigQuery, Dataflow, and AI Platform\n- **Microsoft Azure**: Offers Azure ML, HDInsight, and other data services\n- **IBM Cloud**: Watson Studio and other AI/ML services", 'topic': 'microsoft_dataflow_studio_data', 'topicrank': 0, 'score': 0.4794937392675561}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-25', 'text': "Processing data closer to where it's generated:\n- Reduced latency\n- Lower bandwidth requirements\n- Enhanced privacy\n- Real-time decision making\n- IoT integration", 'topic': 'reduced_lower_time_integration', 'topicrank': 0, 'score': 0.45754144718781053}
# {'id': 'f6274c55dd116e4d32c3d1749b7fc336-2', 'text': 'The first step in any data science project is collecting relevant data. This can come from various sources:\n- Databases\n- APIs\n- Web scraping\n- Sensors and IoT devices\n- Surveys and forms\n- Public datasets', 'topic': 'sources_project_scraping_science', 'topicrank': 0, 'score': 0.40339068301596104}
# {'id': 'ac8955e54f7cabd2e7df4a0372883908-15', 'text': 'GANs consist of two neural networks—a generator and a discriminator—that compete against each other:', 'topic': 'generator_gans_neural_consist', 'topicrank': 0, 'score': 0.30055946392543526}
# {'id': '9aa0b7c49858a94b3ecc16d89059456b-11', 'text': 'Applications include:\n- Image classification\n- Object detection and tracking\n- Facial recognition\n- Autonomous vehicles\n- Medical image analysis', 'topic': 'applications_classification_autonomous_facial', 'topicrank': 0, 'score': 0.24475404620170593}

# %%
def format_graph_context_simple(graph, top_n=10):
    """
    Format graph results with minimal structure.
    
    Args:
        graph: txtai graph object
        top_n: number of top central nodes to include
        
    Returns:
        Formatted string suitable for use as context
    """
    # Get centrality scores
    centrality_scores = graph.centrality()
    
    # Get top N nodes by centrality
    top_nodes = sorted(centrality_scores.keys(), 
                       key=lambda x: centrality_scores[x], 
                       reverse=True)[:top_n]
    
    # Format with minimal structure
    context_parts = []
    
    for i, node_id in enumerate(top_nodes, 1):
        node = graph.node(node_id)
        text = node["text"]
        topic = node.get('topic', f'Concept {i}')
        
        # Add a simple header for each concept
        context_parts.append(f"# {topic}")
        context_parts.append(text)
        context_parts.append("")  # Empty line as separator
    
    return "\n".join(context_parts)

# %%
print("--- GRAPH-BASED SEARCH ---")
print("\n--- RELATIONSHIP QUESTIONS GRAPH SEARCH ---")
for question in relationship_questions:
    print("Q:" + question)
    graph = embeddings.search(question, limit=5, graph=True)
    print(format_graph_context_simple(graph, top_n=10))
# Out:
# --- GRAPH-BASED SEARCH ---
#
# --- RELATIONSHIP QUESTIONS GRAPH SEARCH ---
# Q:How does feature engineering relate to model performance?
# # handling_transforming_log_terms
# Feature engineering is the process of selecting, modifying, or creating new features (variables) to improve model performance:
# - Transforming variables (e.g., log transformation)
# - Creating interaction terms
# - Encoding categorical variables
# - Dimensionality reduction
# - Handling imbalanced data
#
# # counterfactual_shapley_more_additive
# Making complex models more interpretable:
# - LIME (Local Interpretable Model-agnostic Explanations)
# - SHAP (SHapley Additive exPlanations)
# - Feature importance visualization
# - Model-specific interpretation methods
# - Counterfactual explanations
#
# # security_deployed_scaling_ensuring
# Once a model is validated, it can be deployed to production:
# - API development
# - Integration with existing systems
# - Monitoring performance
# - Handling scaling issues
# - Ensuring security
#
# # validation_roc_accuracy_confusion
# Models must be rigorously evaluated to ensure they perform well:
# - Cross-validation
# - Performance metrics (accuracy, precision, recall, F1-score, RMSE, etc.)
# - Confusion matrices
# - ROC curves
# - Residual analysis
#
# # time_clustering_neural_appropriate
# This step involves selecting and training appropriate models:
# - Linear models (regression, logistic regression)
# - Tree-based models (decision trees, random forests, gradient boosting)
# - Support vector machines
# - Neural networks
# - Clustering algorithms
# - Time series models
#
# Q:What is the connection between privacy and ethical data science?
# # recognize_driven_science_lives
# Data science continues to evolve rapidly, driven by technological advances and growing data availability. As organizations increasingly recognize the value of data-driven decision making, the demand for data science expertise will continue to grow. However, with this power comes responsibility—ethical considerations must remain at the forefront as we develop and deploy data science solutions that impact people's lives.
#
# # knowledge_structured_science_scientific
# Data science is an interdisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data. It combines expertise from various fields, including statistics, computer science, information science, and domain knowledge.
#
# # individual_scientists_anonymizing_data
# Data scientists must respect individual privacy:
# - Anonymizing personal data
# - Implementing secure data storage
# - Obtaining proper consent
# - Complying with privacy regulations
# - Minimizing data collection to what's necessary
#
# # data_collection_gdpr_ccpa
# Data collection must be done ethically and in compliance with relevant regulations such as GDPR or CCPA.
#
# # data_initial_layers_hidden
# - **Input Layer**: Receives the initial data
# - **Hidden Layers**: Intermediate layers between input and output
# - **Output Layer**: Produces the final result
#
# Q:How do edge analytics and IoT relate to each other?
# # microsoft_dataflow_studio_data
# - **AWS**: Amazon's cloud platform with services like S3, EC2, SageMaker
# - **Google Cloud Platform**: Includes BigQuery, Dataflow, and AI Platform
# - **Microsoft Azure**: Offers Azure ML, HDInsight, and other data services
# - **IBM Cloud**: Watson Studio and other AI/ML services
#
# # reduced_lower_time_integration
# Processing data closer to where it's generated:
# - Reduced latency
# - Lower bandwidth requirements
# - Enhanced privacy
# - Real-time decision making
# - IoT integration
#
# # sources_project_scraping_science
# The first step in any data science project is collecting relevant data. This can come from various sources:
# - Databases
# - APIs
# - Web scraping
# - Sensors and IoT devices
# - Surveys and forms
# - Public datasets
#
# # generator_gans_neural_consist
# GANs consist of two neural networks—a generator and a discriminator—that compete against each other:
#
# # applications_classification_autonomous_facial
# Applications include:
# - Image classification
# - Object detection and tracking
# - Facial recognition
# - Autonomous vehicles
# - Medical image analysis
